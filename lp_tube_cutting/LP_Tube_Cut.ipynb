# %% [markdown]
# # Linear Programming Tube Cutting
# Using PuLP for linear programming in python. Solving a basic material optimization problem. Determine which parts should be cut on which piece of stock such that scrap material is minimized. All parts and stock are tubes which only have a length. This problem is similar to a 1d bin packing problem.
#
# - $ l_i $ = Length of part i. i = 1, 2, 3, ... n
# - $ M_j $ = Length of stock j. j = 1, 2, 3, ... m
# - $ x_{i,j} $ = {1 if part i is cut on stock j, 0 otherwise}
# - $ y_j $ = {1 if stock j is used, 0 otherwise}
#
# Objective:
# - Minimize the excess stock material after all parts are cut.
#
# $$ min \sum_{j=1}^{m} (M_j * y_j - \sum_{i=1}^{n} l_i * x_{i,j}) $$
#
# Subject to:
# - Total length of parts cut can not exceed stock length. Implies stock must be used if any parts are to be cut on it.
# - All parts must be cut once
#
# $$ M_j * y_j - \sum_{i=1}^{n} x_{i,j} \geq 0 \quad \forall j$$
# $$ \sum_{j=1}^{m} x_{i,j} = 1 \quad \forall i$$

# %%
import pulp
import pandas as pd

# %%
# Test data
# part_df = pd.read_excel("Tube Cut LP Test Data.xlsx", sheet_name= "Test Part Data")
# stock_df = pd.read_excel("Tube Cut LP Test Data.xlsx", sheet_name= "Test Stock Data")

# .049 data
part_df = pd.read_excel("Tube Cut LP Test Data.xlsx", sheet_name= ".049 Part Data")
stock_df = pd.read_excel("Tube Cut LP Test Data.xlsx", sheet_name= ".049 Stock Data")

# # .065 data
# # Part Number, Quantity, Description, Length
# # Quantity is unused?? should remove it??
# part_df = pd.read_excel("Tube Cut LP Test Data.xlsx", sheet_name= ".065 Part Data")

# # Stock Number, Length
# stock_df = pd.read_excel("Tube Cut LP Test Data.xlsx", sheet_name= ".065 Stock Data")

# %%
prob = pulp.LpProblem("Tube_Cut", pulp.LpMinimize)

# %%
# Converts part and stock number to lists
# Could use index numbers instead? It seems implied that part/stock numbers must be unique
# These values are used for i and j. Probably should just become index values
part_list = part_df['Part Number'].to_list()
stock_list = stock_df['Stock Number'].to_list()

# %%
# # All possible pairs between parts and stock
# Is there a easier way to do this? It isn't too bad
part_on_stock = [(i, j) for i in part_list for j in stock_list]

# %%
# Dict of each part number and it's length
part_lengths = dict(zip(part_list, part_df["Length"]))
stock_lengths = dict(zip(stock_list, stock_df["Length"]))

# %%
# variables in dictionary form, indexed by values in part_list, stock_list
# upper and lower bounds of variables are added as constraints
part_vars = pulp.LpVariable.dicts("Part_Stock", (part_list, stock_list), 0, 1, cat= pulp.LpInteger)
stock_vars = pulp.LpVariable.dicts("Stock", stock_list, 0, 1, cat= pulp.LpInteger)

# %%
# It seems like the first thing added to the problem with no constraint given, is assumed to be the objective
# Minimize the difference between the stock length and length of tubes cut on the piece of stock
prob += (pulp.lpSum([stock_lengths[j] * stock_vars[j] - 
                    pulp.lpSum([part_lengths[i] * part_vars[i][j] for i in part_list]) 
                    for j in stock_list]), 
                    "Excess Stock")

# %%
# Requires the tubes cut on stock to not exceed the tube length
# Not sure why I used the <= 0 here
for j in stock_list:
    prob += (pulp.lpSum([part_lengths[i] * part_vars[i][j] for i in part_list]) - stock_lengths[j] * stock_vars[j] <= 0, 
             ("Stock Capacity " + str(j)))

# %%
# All parts must only be cut once on a tube
for i in part_list:
    prob += (pulp.lpSum([part_vars[i][j] for j in stock_list]) - 1 == 0, 
             ("Part Cut " + str(i)))

# %%
print(prob)
prob.solve()
# The status of the solution is printed to the screen
print("Status:", pulp.LpStatus[prob.status])

# Each of the variables is printed with it's resolved optimum value
for v in prob.variables():
    if v.varValue != 0:
        print(v.name, "=", v.varValue)
part_on_stock = [v.varValue for v in prob.variables()]

# The optimised objective function value is printed to the console
print("Excess Material = ", pulp.value(prob.objective))
# Out:
# Tube_Cut:
# MINIMIZE
# -30.59*Part_Stock_19_1 + -30.59*Part_Stock_19_2 + -30.59*Part_Stock_19_3 + -30.59*Part_Stock_19_4 + -30.59*Part_Stock_19_5 + -30.59*Part_Stock_19_6 + -30.59*Part_Stock_19_7 + -30.59*Part_Stock_19_8 + -30.59*Part_Stock_20_1 + -30.59*Part_Stock_20_2 + -30.59*Part_Stock_20_3 + -30.59*Part_Stock_20_4 + -30.59*Part_Stock_20_5 + -30.59*Part_Stock_20_6 + -30.59*Part_Stock_20_7 + -30.59*Part_Stock_20_8 + -14.9*Part_Stock_35_1 + -14.9*Part_Stock_35_2 + -14.9*Part_Stock_35_3 + -14.9*Part_Stock_35_4 + -14.9*Part_Stock_35_5 + -14.9*Part_Stock_35_6 + -14.9*Part_Stock_35_7 + -14.9*Part_Stock_35_8 + -14.9*Part_Stock_36_1 + -14.9*Part_Stock_36_2 + -14.9*Part_Stock_36_3 + -14.9*Part_Stock_36_4 + -14.9*Part_Stock_36_5 + -14.9*Part_Stock_36_6 + -14.9*Part_Stock_36_7 + -14.9*Part_Stock_36_8 + -13.05*Part_Stock_43_1 + -13.05*Part_Stock_43_2 + -13.05*Part_Stock_43_3 + -13.05*Part_Stock_43_4 + -13.05*Part_Stock_43_5 + -13.05*Part_Stock_43_6 + -13.05*Part_Stock_43_7 + -13.05*Part_Stock_43_8 + -13.05*Part_Stock_44_1 + -13.05*Part_Stock_44_2 + -13.05*Part_Stock_44_3 + -13.05*Part_Stock_44_4 + -13.05*Part_Stock_44_5 + -13.05*Part_Stock_44_6 + -13.05*Part_Stock_44_7 + -13.05*Part_Stock_44_8 + -12.13*Part_Stock_47_1 + -12.13*Part_Stock_47_2 + -12.13*Part_Stock_47_3 + -12.13*Part_Stock_47_4 + -12.13*Part_Stock_47_5 + -12.13*Part_Stock_47_6 + -12.13*Part_Stock_47_7 + -12.13*Part_Stock_47_8 + -12.13*Part_Stock_48_1 + -12.13*Part_Stock_48_2 + -12.13*Part_Stock_48_3 + -12.13*Part_Stock_48_4 + -12.13*Part_Stock_48_5 + -12.13*Part_Stock_48_6 + -12.13*Part_Stock_48_7 + -12.13*Part_Stock_48_8 + -6.09*Part_Stock_49_1 + -6.09*Part_Stock_49_2 + -6.09*Part_Stock_49_3 + -6.09*Part_Stock_49_4 + -6.09*Part_Stock_49_5 + -6.09*Part_Stock_49_6 + -6.09*Part_Stock_49_7 + -6.09*Part_Stock_49_8 + -6.09*Part_Stock_50_1 + -6.09*Part_Stock_50_2 + -6.09*Part_Stock_50_3 + -6.09*Part_Stock_50_4 + -6.09*Part_Stock_50_5 + -6.09*Part_Stock_50_6 + -6.09*Part_Stock_50_7 + -6.09*Part_Stock_50_8 + -22.43*Part_Stock_66_1 + -22.43*Part_Stock_66_2 + -22.43*Part_Stock_66_3 + -22.43*
#  + Part_Stock_19_4 + Part_Stock_19_5 + Part_Stock_19_6 + Part_Stock_19_7
#  + Part_Stock_19_8 = 1
#
# Part_Cut_20: Part_Stock_20_1 + Part_Stock_20_2 + Part_Stock_20_3
#  + Part_Stock_20_4 + Part_Stock_20_5 + Part_Stock_20_6 + Part_Stock_20_7
#  + Part_Stock_20_8 = 1
#
# Part_Cut_66: Part_Stock_66_1 + Part_Stock_66_2 + Part_Stock_66_3
#  + Part_Stock_66_4 + Part_Stock_66_5 + Part_Stock_66_6 + Part_Stock_66_7
#  + Part_Stock_66_8 = 1
#
# Part_Cut_47: Part_Stock_47_1 + Part_Stock_47_2 + Part_Stock_47_3
#  + Part_Stock_47_4 + Part_Stock_47_5 + Part_Stock_47_6 + Part_Stock_47_7
#  + Part_Stock_47_8 = 1
#
# Part_Cut_48: Part_Stock_48_1 + Part_Stock_48_2 + Part_Stock_48_3
#  + Part_Stock_48_4 + Part_Stock_48_5 + Part_Stock_48_6 + Part_Stock_48_7
#  + Part_Stock_48_8 = 1
#
# Part_Cut_68: Part_Stock_68_1 + Part_Stock_68_2 + Part_Stock_68_3
#  + Part_Stock_68_4 + Part_Stock_68_5 + Part_Stock_68_6 + Part_Stock_68_7
#  + Part_Stock_68_8 = 1
#
# Part_Cut_67: Part_Stock_67_1 + Part_Stock_67_2 + Part_Stock_67_3
#  + Part_Stock_67_4 + Part_Stock_67_5 + Part_Stock_67_6 + Part_Stock_67_7
#  + Part_Stock_67_8 = 1
#
# Part_Cut_49: Part_Stock_49_1 + Part_Stock_49_2 + Part_Stock_49_3
#  + Part_Stock_49_4 + Part_Stock_49_5 + Part_Stock_49_6 + Part_Stock_49_7
#  + Part_Stock_49_8 = 1
#
# Part_Cut_50: Part_Stock_50_1 + Part_Stock_50_2 + Part_Stock_50_3
#  + Part_Stock_50_4 + Part_Stock_50_5 + Part_Stock_50_6 + Part_Stock_50_7
#  + Part_Stock_50_8 = 1
#
# Part_Cut_72: Part_Stock_72_1 + Part_Stock_72_2 + Part_Stock_72_3
#  + Part_Stock_72_4 + Part_Stock_72_5 + Part_Stock_72_6 + Part_Stock_72_7
#  + Part_Stock_72_8 = 1
#
# VARIABLES
# 0 <= Part_Stock_19_1 <= 1 Integer
# 0 <= Part_Stock_19_2 <= 1 Integer
# 0 <= Part_Stock_19_3 <= 1 Integer
# 0 <= Part_Stock_19_4 <= 1 Integer
# 0 <= Part_Stock_19_5 <= 1 Integer
# 0 <= Part_Stock_19_6 <= 1 Integer
# 0 <= Part_Stock_19_7 <= 1 Integer
# 0 <= Part_Stock_19_8 <= 1 Integer
# 0 <= Part_Stock_20_1 <= 1 Integer
# 0 <= Part_Stock_20_2 <= 1 Integer
# 0 <= Part_Stock_20_3 <= 1 Integer
# 0 <= Part_Stock_20_4 <= 1 Integer
# 0 <= Part_Stock_20_5 <= 1 Integer
# 0 <= Part_Stock_20_6 <= 1 Integer
# 0 <= Part_Stock_20_7 <= 1 Integer
# 0 <= Part_Stock_20_8 <= 1 Integer
# 0 <= Part_Stock_35_1 <= 1 Integer
# 0 <= Part_Stock_35_2 <= 1 Integer
# 0 <= Part_Stock_35_3 <= 1 Integer
# 0 <= Part_Stock_35_4 <= 1 Integer
# 0 <= Part_Stock_35_5 <= 1 Integer
# 0 <= Part_Stock_35_6 <= 1 Integer
# 0 <= Part_Stock_35_7 <= 1 Integer
# 0 <= Part_Stock_35_8 <= 1 Integer
# 0 <= Part_Stock_36_1 <= 1 Integer
# 0 <= Part_Stock_36_2 <= 1 Integer
# 0 <= Part_Stock_36_3 <= 1 Integer
# 0 <= Part_Stock_36_4 <= 1 Integer
# 0 <= Part_Stock_36_5 <= 1 Integer
# 0 <= Part_Stock_36_6 <= 1 Integer
# 0 <= Part_Stock_36_7 <= 1 Integer
# 0 <= Part_Stock_36_8 <= 1 Integer
# 0 <= Part_Stock_43_1 <= 1 Integer
# 0 <= Part_Stock_43_2 <= 1 Integer
# 0 <= Part_Stock_43_3 <= 1 Integer
# 0 <= Part_Stock_43_4 <= 1 Integer
# 0 <= Part_Stock_43_5 <= 1 Integer
# 0 <= Part_Stock_43_6 <= 1 Integer
# 0 <= Part_Stock_43_7 <= 1 Integer
# 0 <= Part_Stock_43_8 <= 1 Integer
# 0 <= Part_Stock_44_1 <= 1 Integer
# 0 <= Part_Stock_44_2 <= 1 Integer
# 0 <= Part_Stock_44_3 <= 1 Integer
# 0 <= Part_Stock_44_4 <= 1 Integer
# 0 <= Part_Stock_44_5 <= 1 Integer
# 0 <= Part_Stock_44_6 <= 1 Integer
# 0 <= Part_Stock_44_7 <= 1 Integer
# 0 <= Part_Stock_44_8 <= 1 Integer
# 0 <= Part_Stock_47_1 <= 1 Integer
# 0 <= Part_Stock_47_2 <= 1 Integer
# 0 <= Part_Stock_47_3 <= 1 Integer
# 0 <= Part_Stock_47_4 <= 1 Integer
# 0 <= Part_Stock_47_5 <= 1 Integer
# 0 <= Part_Stock_47_6 <= 1 Integer
# 0 <= Part_Stock_47_7 <= 1 Integer
# 0 <= Part_Stock_47_8 <= 1 Integer
# 0 <= Part_Stock_48_1 <= 1 Integer
# 0 <= Part_Stock_48_2 <= 1 Integer
# 0 <= Part_Stock_48_3 <= 1 Integer
# 0 <= Part_Stock_48_4 <= 1 Integer
# 0 <= Part_Stock_48_5 <= 1 Integer
# 0 <= Part_Stock_48_6 <= 1 Integer
# 0 <= Part_Stock_48_7 <= 1 Integer
# 0 <= Part_Stock_48_8 <= 1 Integer
# 0 <= Part_Stock_49_1 <= 1 Integer
# 0 <= Part_Stock_49_2 <= 1 Integer
# 0 <= Part_Stock_49_3 <= 1 Integer
# 0 <= Part_Stock_49_4 <= 1 Integer
# 0 <= Part_Stock_49_5 <= 1 Integer
# 0 <= Part_Stock_49_6 <= 1 Integer
# 0 <= Part_Stock_49_7 <= 1 Integer
# 0 <= Part_Stock_49_8 <= 1 Integer
# 0 <= Part_Stock_50_1 <= 1 Integer
# 0 <= Part_Stock_50_2 <= 1 Integer
# 0 <= Part_Stock_50_3 <= 1 Integer
# 0 <= Part_Stock_50_4 <= 1 Integer
# 0 <= Part_Stock_50_5 <= 1 Integer
# 0 <= Part_Stock_50_6 <= 1 Integer
# 0 <= Part_Stock_50_7 <= 1 Integer
# 0 <= Part_Stock_50_8 <= 1 Integer
# 0 <= Part_Stock_66_1 <= 1 Integer
# 0 <= Part_Stock_66_2 <= 1 Integer
# 0 <= Part_Stock_66_3 <= 1 Integer
# 0 <= Part_Stock_66_4 <= 1 Integer
# 0 <= Part_Stock_66_5 <= 1 Integer
# 0 <= Part_Stock_66_6 <= 1 Integer
# 0 <= Part_Stock_66_7 <= 1 Integer
# 0 <= Part_Stock_66_8 <= 1 Integer
# 0 <= Part_Stock_67_1 <= 1 Integer
# 0 <= Part_Stock_67_2 <= 1 Integer
# 0 <= Part_Stock_67_3 <= 1 Integer
# 0 <= Part_Stock_67_4 <= 1 Integer
# 0 <= Part_Stock_67_5 <= 1 Integer
# 0 <= Part_Stock_67_6 <= 1 Integer
# 0 <= Part_Stock_67_7 <= 1 Integer
# 0 <= Part_Stock_67_8 <= 1 Integer
# 0 <= Part_Stock_68_1 <= 1 Integer
# 0 <= Part_Stock_68_2 <= 1 Integer
# 0 <= Part_Stock_68_3 <= 1 Integer
# 0 <= Part_Stock_68_4 <= 1 Integer
# 0 <= Part_Stock_68_5 <= 1 Integer
# 0 <= Part_Stock_68_6 <= 1 Integer
# 0 <= Part_Stock_68_7 <= 1 Integer
# 0 <= Part_Stock_68_8 <= 1 Integer
# 0 <= Part_Stock_72_1 <= 1 Integer
# 0 <= Part_Stock_72_2 <= 1 Integer
# 0 <= Part_Stock_72_3 <= 1 Integer
# 0 <= Part_Stock_72_4 <= 1 Integer
# 0 <= Part_Stock_72_5 <= 1 Integer
# 0 <= Part_Stock_72_6 <= 1 Integer
# 0 <= Part_Stock_72_7 <= 1 Integer
# 0 <= Part_Stock_72_8 <= 1 Integer
# 0 <= Stock_1 <= 1 Integer
# 0 <= Stock_2 <= 1 Integer
# 0 <= Stock_3 <= 1 Integer
# 0 <= Stock_4 <= 1 Integer
# 0 <= Stock_5 <= 1 Integer
# 0 <= Stock_6 <= 1 Integer
# 0 <= Stock_7 <= 1 Integer
# 0 <= Stock_8 <= 1 Integer
#
# Status: Optimal
# Part_Stock_19_3 = 1.0
# Part_Stock_20_2 = 1.0
# Part_Stock_35_5 = 1.0
# Part_Stock_36_2 = 1.0
# Part_Stock_43_3 = 1.0
# Part_Stock_44_2 = 1.0
# Part_Stock_47_7 = 1.0
# Part_Stock_48_5 = 1.0
# Part_Stock_49_7 = 1.0
# Part_Stock_50_2 = 1.0
# Part_Stock_66_7 = 1.0
# Part_Stock_67_3 = 1.0
# Part_Stock_68_5 = 1.0
# Part_Stock_72_7 = 1.0
# Stock_2 = 1.0
# Stock_3 = 1.0
# Stock_5 = 1.0
# Stock_7 = 1.0
# Excess Material =  22.889999999999997

# %%
# part_on_stock
# print(part_on_stock)
# print(part_vars)
# prob.variables()[0]

for j in stock_list:
    print(j)
    for i in part_list:
        if part_vars[i][j].varValue != 0:
            print(str(part_vars[i][j]) + ": " + str(part_vars[i][j].varValue))
# Out:
# 1
# 2
# Part_Stock_36_2: 1.0
# Part_Stock_44_2: 1.0
# Part_Stock_20_2: 1.0
# Part_Stock_50_2: 1.0
# 3
# Part_Stock_43_3: 1.0
# Part_Stock_19_3: 1.0
# Part_Stock_67_3: 1.0
# 4
# 5
# Part_Stock_35_5: 1.0
# Part_Stock_48_5: 1.0
# Part_Stock_68_5: 1.0
# 6
# 7
# Part_Stock_66_7: 1.0
# Part_Stock_47_7: 1.0
# Part_Stock_49_7: 1.0
# Part_Stock_72_7: 1.0
# 8
